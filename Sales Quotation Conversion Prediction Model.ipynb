# %%
import pandas as pd
import numpy as np
data =  pd.read_excel("C:\\Users\\SHREYAS N\\Documents\\Sales Quotation Sample Dataset.xlsx", sheet_name = "Sheet1")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Product_ID                        25 non-null     object
#  1   Sales Quotation                   25 non-null     int64
#  2   Converted Quotation               25 non-null     int64
#  3   Conversion Rate                   25 non-null     float64
#  4   Quotation Item Qty                25 non-null     int64
#  5   Open Quotation                    25 non-null     int64
#  6   No of Open Items                  25 non-null     int64
#  7   Expired Quotation                 25 non-null     int64
#  8   No. of Expired Items              25 non-null     int64
#  9   Expiring Quotations               25 non-null     int64
#  10  No. of Expiring Items             25 non-null     int64
#  11  Rejected Quotations               25 non-null     int64
# ...

# %%
data.head()
# Out:
#       Product_ID  Sales Quotation  Converted Quotation  Conversion Rate  \
# 0  MetalProduct1            50000                40000         0.800000
# 1  MetalProduct1           100000               100000         1.000000
# 2  MetalProduct2           500000                40000         0.080000
# 3  MetalProduct2          7896666               105667         0.013381
# 4  MetalProduct1           580000               400000         0.689655
#
#    Quotation Item Qty  Open Quotation  No of Open Items  Expired Quotation  \
# 0                 100           10000                10                  0
# 1                 300               0                 0                  0
# 2                 874          460000                10                  0
# 3                 700         7790999               600                  0
# 4                 456          180000                10              60000
#
#    No. of Expired Items  Expiring Quotations  No. of Expiring Items  \
# ...

# %%
data.corr()
# Out:
#                                   Sales Quotation  Converted Quotation  \
# Sales Quotation                          1.000000             0.949361
# Converted Quotation                      0.949361             1.000000
# Conversion Rate                          0.219222             0.364682
# Quotation Item Qty                      -0.186828            -0.267801
# Open Quotation                           0.229494            -0.087836
# No of Open Items                         0.025154            -0.097740
# Expired Quotation                       -0.238501            -0.163155
# No. of Expired Items                    -0.259965            -0.177704
# Expiring Quotations                      0.088253            -0.079013
# No. of Expiring Items                   -0.075525            -0.227794
# Rejected Quotations                     -0.341906            -0.224662
# No. of Rejected Items                   -0.410992            -0.273721
# ...

# %%
data = pd.get_dummies(data)

# %%
data.head()
# Out:
#    Sales Quotation  Converted Quotation  Conversion Rate  Quotation Item Qty  \
# 0            50000                40000         0.800000                 100
# 1           100000               100000         1.000000                 300
# 2           500000                40000         0.080000                 874
# 3          7896666               105667         0.013381                 700
# 4           580000               400000         0.689655                 456
#
#    Open Quotation  No of Open Items  Expired Quotation  No. of Expired Items  \
# 0           10000                10                  0                     0
# 1               0                 0                  0                     0
# 2          460000                10                  0                     0
# 3         7790999               600                  0                     0
# 4          180000                10              60000                    56
#
# ...

# %%
data = data.drop(["Predicted Conversion Probability"], axis=1)

# %%
data[['Conversion Rate']] = data[['Conversion Rate']]*100

# %%
X = data[['Conversion Rate']]
#Y = data['Converted Quotation','Sales Quotation', 'Expiring Quotations', 'Product_ID_MetalProduct1','Product_ID_MetalProduct2', 'Product_ID_MetalProduct3', 'Inquiry Channel_Email','Inquiry Channel_Internal Sales Lead-PersonA' ]

# %%
Y = data[['Sales Quotation', 'Expiring Quotations', 'Product_ID_MetalProduct1','Product_ID_MetalProduct2', 'Product_ID_MetalProduct3', 'Inquiry Channel_Email','Inquiry Channel_Internal Sales Lead-PersonA'] ]

# %%
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
X_train, X_test, y_train, y_test = train_test_split(Y, X, test_size=0.2, random_state=42)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_)
# Out:
# [46.20728657]
# [[ 5.01585511e-07  2.10032593e-07  3.82620247e+01 -3.88952826e+01
#    6.33257954e-01  4.72733446e+00 -4.72733446e+00]]

# %%
predictions = regressor.predict(X_test)
predictions
# Out:
# array([[79.91528845],
#        [12.07407918],
#        [89.22277512],
#        [51.80969018],
#        [89.22720787]])

# %%
# importing r2_score module
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# predicting the accuracy score
score=r2_score(y_test,predictions)

print('r2 socre is' ,score)

print('mean_sqrd_error is==',mean_squared_error(y_test,predictions))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,predictions)))
# Out:
# r2 socre is 0.8848592486849004
# mean_sqrd_error is== 115.7652401809158
# root_mean_squared error of is== 10.759425643635248

# %%
print("Actual","Predicted", y_test,predictions )
# Out:
# Actual Predicted     Conversion Rate
# 8         99.000099
# 16         8.000000
# 0         80.000000
# 23        50.000000
# 11        78.755172 [[80.64382447]
#  [13.27587995]
#  [87.4252554 ]
#  [50.5575035 ]
#  [87.42752498]]

# %%
import pickle 
pickle_out = open("classifier.pkl", mode = "wb") 
pickle.dump(regressor, pickle_out) 
pickle_out.close()
